# %%
import numpy as np
import matplotlib.pyplot as plt
from RZutilpy.figure import bar, plot, default_img_set, colorpalettable
default_img_set()
import seaborn as sns

# %%
decoding_tp1 = np.load("M1_decoding_twindow.npz", allow_pickle=True)['decoding_tp1']
decoding_tp2 = np.load("M1_decoding_twindow.npz", allow_pickle=True)['decoding_tp2']
improvement = (decoding_tp2 - decoding_tp1)[:,:,6:8].sum(axis=2)
sns.heatmap(improvement,vmin=0.08)
# Out:
# <AxesSubplot:>

# %%
decoding_tp1 = np.load("M2_decoding_twindow.npz")['decoding_tp1']
decoding_tp2 = np.load("M2_decoding_twindow.npz")['decoding_tp2']
improvement = (decoding_tp2 - decoding_tp1)[:,:,6:8].sum(axis=2)
sns.heatmap(improvement, vmin=0.21, vmax=0.24)
# Out:
# <AxesSubplot:>
